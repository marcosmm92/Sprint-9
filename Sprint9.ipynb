# %% [markdown]
# # SPRINT 9: Creació de funcions, estructures de dades i bucles

# %% [markdown]
# ## NIVELL 1

# %% [markdown]
# 1. Calculadora de l'índex de massa corporal
#
# Escriu una funció que calculi l'IMC ingressat per l'usuari/ària, és a dir, qui ho executi haurà d'ingressar aquestes dades.
#
# La funció ha de classificar el resultat en les seves respectives categories.
#
# Consell: Intenta validar les dades prèviament, perquè enviï un missatge d’advertència si les dades introduïdes per l’usuari/a no estan en el format adequat o no pren valors raonables.

# %%
def calculadora_imc():
    """
    Calcula el IMC y lo clasifica según la OMS.
    Datos solicitados al usuario: peso (kg) y altura (m).
    """

    # Validamos el peso
    while True:
        dato_peso = input("Por favor, introduce tu peso en kg (ej: 75.5): ").replace(",",".")
        try:
            peso = float(dato_peso)
            if peso <= 0:
                print("El peso debe ser un número positivo.")
            elif peso < 20 or peso > 300:
                print("El peso se encuentra fuera del rango habitual. Por favor, compruébalo.")
            else:
                break
        except ValueError:
            print("Entrada errónea. Vuelve a añadirlo correctamente, por favor.")

    # Validamos la altura
    while True:
        dato_altura = input("Por favor, introduce tu altura en metros (ej: 1.78): ").replace(",",".")
        try:
            altura = float(dato_altura)
            if altura <= 0:
                print("La altura debe ser un número positivo.")
            elif altura < 0.5 or altura > 2.5:
                print("La altura se encuentra fuera del rango habitual. Por favor, compruébala.")
            else:
                break
        except ValueError:
            print("Entrada errónea. Vuelve a añadirla correctamente, por favor.")


    # Calculamos el IMC
    imc = peso / (altura ** 2)

    # Clasificamos según la OMS
    if imc < 18.5:
        categoria = "Bajo peso"
    elif imc < 25:
        categoria = "Peso normal"  
    elif imc < 30:
        categoria = "Sobrepeso"
    else:
        categoria = "Obesidad"

    # Mostramos los resultados
    print(f"Peso: {peso} kg")
    print(f"Altura: {altura} m")
    print(f"\nTu IMC es: {imc:.2f}")
    print(f"Clasificación: {categoria}")

    return imc, categoria

# Ejecutamos la función
calculadora_imc()
# Out:
# Entrada errónea. Vuelve a añadirlo correctamente, por favor.
# El peso se encuentra fuera del rango habitual. Por favor, compruébalo.
# La altura se encuentra fuera del rango habitual. Por favor, compruébala.
# Peso: 76.5 kg
# Altura: 1.83 m
#
# Tu IMC es: 22.84
# Clasificación: Peso normal
# (22.84332168771835, 'Peso normal')

# %% [markdown]
# 2. Convertidor de temperatures
#
# Existeixen diverses unitats de temperatura utilitzades en diferents contextos i regions. Les més comunes són Celsius (°C), Fahrenheit (°F) i Kelvin (K). També existeixen altres unitats com Rankine (°Ra) i Réaumur (°Re).
#
# Selecciona almenys 2 conversors, de tal manera que en introduir una temperatura retorni, com a mínim, dues conversions, de manera que es puguin guardar (recorda que un print() no es pot guardar mai).
#
# Consell: Intenta validar les dades prèviament, perquè enviï un missatge d’advertència si les dades introduides per l’usuari/a no estan en el format adequat.
#
# (EXTRA): Pensa una manera d’emmagatzemar totes les possibles conversions en un sol objecte (Llista? Diccionari? DataFrame?) en comptes d’escriure molts if else en funció de la temperatura d’origen i la temperatura de destí.

# %%
def convertir_temperatura():
    """
    Convierte temperaturas entre Celsius, Fahrenheit, Kelvin y Rankine.
    Solicita al usuario una unidad de temperatura de origen y un valor numérico,
    realiza las conversiones y devuelve un diccionario con los resultados.
    """
    
    # Solicitamos una unidad de temperatura y la validamos
    while True:
        unidad = input("Introduce la unidad de la temperatura (C, F, K, RA): ").strip().upper()
        if unidad in ("C", "F", "K", "RA"):
            break
        print("ERROR: Unidad no válida. Por favor, usa C, F, K o RA.")

    # Solicitamos el valor numérico de la temperatura y lo validamos
    while True:
        try:
            valor = float(input(f"Introduce la temperatura en {unidad}: "))
            if unidad in ("K", "RA") and valor < 0:
                print("ERROR: Esa temperatura no puede ser negativa.")
                continue
            break
        except ValueError:
            print("ERROR: Debes introducir un número válido.")

    # Conversión de la temperatura a Celsius
    match unidad:
        case "C":
            c = valor

        case "F":
            c = (valor - 32) * 5/9

        case "K":
            c = valor - 273.15

        case "RA":
            c = (valor - 491.67) * 5/9

    # Desde Celsius calculamos el resto
    f = c * 9/5 + 32
    k = c + 273.15
    ra = k * 9/5

   # Creamos un diccionario con los resultados
    conversiones = {
        "Celsius": round(c, 2),
        "Fahrenheit": round(f, 2),
        "Kelvin": round(k, 2),
        "Rankine": round(ra, 2)
    }

    return conversiones

# Ejecutamos la función y mostramos el resultado
resultado = convertir_temperatura()
print(resultado)
# Out:
# ERROR: Unidad no válida. Por favor, usa C, F, K o RA.
# ERROR: Esa temperatura no puede ser negativa.
# {'Celsius': -73.15, 'Fahrenheit': -99.67, 'Kelvin': 200.0, 'Rankine': 360.0}

# %% [markdown]
# 3. Comptador de paraules d'un text.
#
# Escriu una funció que donat un text, mostri les vegades que apareix cada paraula. Intenta que es gestionin totes les casuístiques possibles que facin que el programa no funcioni correctament.
#
# (EXTRA): Quina és la llargada mitjana de les paraules del text que has escrit? “Hola com va?” hauria de retornar (4+3+2) / 3 = 3

# %%
def analizar_frase(frase):
    """
    Analiza un texto contando la frecuencia de cada palabra
    y calculando la longitud media de las palabras.

    Parámetros: frase (str).

    Devuelve:
    dict: número de apariciones de cada palabra
    dict: longitud de cada palabra
    float: longitud media de las palabras
    """
    
    # Definimos los signos de puntuación que deseamos eliminar
    puntuacion = "?!,.:;¡¿()[]{}\"'"

    # Lo convertimos todo a minúsculas
    frase_limpia = frase.lower()

    # Eliminamos la puntuación
    for signo in puntuacion:
        frase_limpia = frase_limpia.replace(signo, "") 

    # Separamos la frase en palabras
    palabras = frase_limpia.split() 

    # Creamos la estructura para contar
    contador_palabras = {}
    contador_letras = {}
    total_letras = 0

    for palabra in palabras:
        # Contamos cuántas veces aparece cada palabra
        if palabra in contador_palabras:
            contador_palabras[palabra] += 1 
        else:
            contador_palabras[palabra] = 1
        # Contamos las letras de cada palabra
        num_letras = len(palabra) 
        contador_letras[palabra] = num_letras

        # Acumulamos el total de letras
        total_letras += num_letras

    # Calculamos el promedio, evitando que nos dé error si la frase está vacía
    promedio = total_letras / len(palabras) if palabras else 0

    # Devolvemos los resultados
    return contador_palabras, contador_letras, promedio

# Solicitamos una frase y mostramos el resultado
frase = input("Introduce una frase: ")

conteo, letras, promedio = analizar_frase(frase)

print(f"Conteo de palabras: {conteo}")
print(f"Letras por palabra: {letras}")
print(f"Promedio de letras por palabra: {promedio:.2f}")
# Out:
# Conteo de palabras: {'el': 2, 'barça': 1, 'ganó': 1, 'la': 1, 'liga': 1, 'pasado': 1, 'domingo': 1}
# Letras por palabra: {'el': 2, 'barça': 5, 'ganó': 4, 'la': 2, 'liga': 4, 'pasado': 6, 'domingo': 7}
# Promedio de letras por palabra: 4.00

# %% [markdown]
# 4. Diccionari invers (amb possibilitat de duplicats)
#
# Resulta que el client té una enquesta molt antiga que s'emmagatzema en un diccionari i els resultats els necessita al revés, és a dir, intercanviant les claus i els valors. Els valors i claus en el diccionari original són únics; si aquest no és el cas, la funció hauria d'imprimir un missatge d'advertiment, juntament amb una llista amb els valors associats a la clau repetida.

# %%
def diccionario_inverso(dic):
    """
    Invierte un diccionario intercambiando claves por valores.

    Si hay valores duplicados, los agrupa en una lista y muestra
    un mensaje de advertencia indicando las claves asociadas.

    Args:
    dic: Diccionario de entrada con claves y valores.

    Returns:
    dict: Diccionario invertido donde cada valor del original
    se convierte en clave, y su valor es una única clave o una
    lista de claves si hay duplicados.
    """

    # Creamos los diccionarios donde se guardará el resultado y los valores repetidos
    inverso = {}
    duplicados = {}

    # Agrupamos todo en listas primero
    for clave, valor in dic.items():
        if valor not in inverso:
            inverso[valor] = [clave]
        else:
            inverso[valor].append(clave)
            duplicados.setdefault(valor, []).append(clave)

    # Convertimos listas de un solo elemento a valor simple
    resultado = {}
    for valor, claves in inverso.items():
        if len(claves) == 1:
            resultado[valor] = claves[0]
        else:
            resultado[valor] = claves

    # Mostramos el aviso si hay duplicados
    if duplicados:
        print("Aviso: hay claves repetidas al invertir el diccionario.\n")
        for valor, claves in duplicados.items():
            print(f"El valor '{valor}' está asociado a las claves: {claves}")

    return resultado

# Ejecutamos la función con un ejemplo
dic = {"a": 1, "b": 2, "c": 2, "d": 1, "e": 1, "f": 3}
resultado = diccionario_inverso(dic)
print("\nResultado:", resultado)
# Out:
# Aviso: hay claves repetidas al invertir el diccionario.
#
# El valor '2' está asociado a las claves: ['c']
# El valor '1' está asociado a las claves: ['d', 'e']
#
# Resultado: {1: ['a', 'd', 'e'], 2: ['b', 'c'], 3: 'f'}

# %% [markdown]
# ## NIVELL 2

# %% [markdown]
# 1. Comptador i endreçador de paraules d'un text.
#
# El client va quedar content amb el comptador de paraules, però ara vol llegir arxius TXT i que calculi la freqüència de cada paraula ordenades dins de les entrades habituals del diccionari segons la lletra amb la qual comencen, és a dir, les claus han d'anar de la A a la Z i dins de la A hem d'anar de la A la Z.

# %%
def contar_palabras_por_letra(nombre_archivo):
    """
    Lee un archivo de texto y devuelve un diccionario con la frecuencia de palabras
    agrupadas por su letra inicial (A-Z).
    """

    # Abrimos y leemos el archivo y lo convertimos todo a minúsculas
    with open(nombre_archivo, 'r', encoding='utf-8') as f:
        texto = f.read().lower()

    # Extraemos palabras, incluyendo tildes, ñ y diéresis
    import re
    palabras = re.findall(r"[A-Za-zÁÉÍÓÚáéíóúñÑüÜ]+", texto)

    # Contamos cuántas veces aparece cada palabra
    contador = {}
    for palabra in palabras:
        contador[palabra] = contador.get(palabra, 0) + 1

    # Creamos la estructura A-Z y agrupamos por la letra inicial
    dicc_a_z = {letra: {} for letra in "ABCDEFGHIJKLMNOPQRSTUVWXYZ"}

    for palabra, frecuencia in contador.items():
        inicial = palabra[0].upper()

        if inicial in dicc_a_z:
            dicc_a_z[inicial][palabra] = frecuencia

    # Ordenamos alfabéticamente cada subdiccionario
    dicc_a_z = {
        letra: dict(sorted(subdicc.items()))
        for letra, subdicc in dicc_a_z.items()
    }

    return dicc_a_z

# Llamada a la función
contar_palabras_por_letra('tu me quieres blanca.txt')
# Out:
# {'A': {'a': 3,
#   'agua': 1,
#   'al': 2,
#   'alba': 4,
#   'alcobas': 1,
#   'alimenta': 1,
#   'alma': 1,
#   'amarga': 1,
#   'azucena': 1},
#  'B': {'baco': 1,
#   'banquete': 1,
#   'bebe': 1,
#   'blanca': 3,
#   'boca': 1,
#   'bosques': 1,
#   'buen': 1},
#  'C': {'cabañas': 1,
#   'carnes': 2,
#   'casta': 3,
#   'cerrada': 1,
#   'con': 4,
#   'conservas': 1,
#   'copas': 1,
#   'corola': 1,
#   'corriste': 1,
#   'cuando': 2,
#   'cubierto': 1,
#   'cuerpo': 1,
#   'cuáles': 1},
#  'D': {'de': 8, 'dejaste': 1, 'del': 1, 'diga': 1, 'dios': 2, 'duerme': 1},
#  'E': {'el': 4,
#   'ellas': 1,
#   'en': 4,
#   'engaño': 1,
#   'enredada': 1,
#   'entonces': 1,
#   'escarcha': 1,
#   'espumas': 1,
#   'esqueleto': 1,
#   'estrago': 1},
#  'F': {'festejando': 1, 'filtrado': 1, 'frutos': 1},
#  'G': {},
#  'H': {'habla': 1,
#   'hacia': 1,
#   'haya': 1,
#   'hayas': 1,
#   'hermana': 1,
#   'hombre': 1,
#   'hubiste': 1,
#   'huye': 1},
#  'I': {'intacto': 1},
# ...

# %% [markdown]
# 2. Conversió de tipus de dades.
#
# El client rep una llista de dades i necessita generar dues llistes, la primera on estaran tots els elements que es van poder convertir en flotants i l'altra on estan els elements que no es van poder convertir.

# %%
lista = ['1.3', 'one', '1e10', 'seven', '3-1/2', ('2',1,1.4,'not-a-number'), [1,2,'3','3.4']]

# Generamos las dos Listas
flotantes = []
no_convertibles = []

def extraer_flotantes(obj):
    """
    Recorre recursivamente una estructura (listas y tuplas) y separa sus elementos en:
    - valores convertibles a float (se almacenan en 'flotantes')
    - valores no convertibles (se almacenan en 'no_convertibles')
    """
    
    # Caso números
    if isinstance(obj, (float, int)):
        flotantes.append(float(obj))

    # Caso strings
    elif isinstance(obj, str):
        try:
            flotantes.append(float(obj))
        except ValueError:
            no_convertibles.append(obj)

    # Caso listas o tuplas para entrar en estructuras anidadas
    elif isinstance(obj, (list, tuple)):
        for item in obj:
            extraer_flotantes(item)

# Llamamos la función
extraer_flotantes(lista)

print("Flotantes:", flotantes)
print("No flotantes:", no_convertibles)
# Out:
# Flotantes: [1.3, 10000000000.0, 2.0, 1.0, 1.4, 1.0, 2.0, 3.0, 3.4]
# No flotantes: ['one', 'seven', '3-1/2', 'not-a-number']

# %% [markdown]
# ## NIVELL 3

# %% [markdown]
# 1. Generador de Contrasenyes
#
# Explora el funcionament del mòdul random de la llibreria numpy.
#
# En aquest punt, el client ha detectat un problema amb les contrasenyes que utilitzen els seus treballadors. Asdf1234, dates d’aniversari o similars. Per a solucionar-ho ens ha encarregat una funció de Python que generi contrasenyes més segures. La funció ha de dependre dels següents paràmetres:
#
# longitud (int): Longitud de la contrasenya
# majuscules (bool = True): Si hi ha d’aparèixer majúscules
# minuscules (bool = True): Si hi ha d’aparèixer minúscules
# numeros (bool = True): Si hi ha d’aparèixer números
# signes (bool = False): Si hi ha d’aparèixer caràcters especials (,-$? o similars)
# Així doncs, si executem la funció de la següent manera:
#
# crear_contrasenya(10, True, True, True, True)
#
# Hauríem d’obtenir un output (que hem de poder guardar) de l’estil:
#
# 9Er,5Vn8P$
#
# Assegura’t que es compleixin tots els criteris, i que aquestes contrasenyes siguin realment aleatòries.
#
# (EXTRA) Explora com podríem fer que la funció copiés la contrasenya automàticament al porta papers de l’ordinador (com si l’haguéssim seleccionat i fet ctrl+copy).

# %%
import numpy as np
import pyperclip

# Definimos los caracteres disponibles
MAYUSCULAS = np.array([chr(i) for i in range(ord('A'), ord('Z') + 1)])
MINUSCULAS = np.array([chr(i) for i in range(ord('a'), ord('z') + 1)])
NUMEROS = np.array([str(i) for i in range(10)])
SIMBOLOS = np.array(list("!@#$%^&*()-_=+,.?/"))

def crear_contrasenya(longitud, mayusculas=True, minusculas=True, numeros=True, simbolos=False):
    """
    Genera una contraseña aleatoria con NumPy según longitud y tipos de caracteres.
    Parámetros:
    longitud (int): Longitud de la contraseña.
    mayusculas (bool): Incluir mayúsculas.
    minusculas (bool): Incluir minúsculas.
    numeros (bool): Incluir dígitos.
    signos (bool): Incluir caracteres especiales.

    Retorna:
    str: Contraseña generada aleatoriamente.
    """
    # Creamos lista de grupos y añadimos según parámetros
    grupos = []

    if mayusculas:
        grupos.append(MAYUSCULAS)
    if minusculas:
        grupos.append(MINUSCULAS)
    if numeros:
        grupos.append(NUMEROS)
    if simbolos: 
        grupos.append(SIMBOLOS)
    
    # Validamos y evitamos contraseñas vacías
    if not grupos:
        raise ValueError("Debe activarse al menos un tipo de carácter.")
    
    # Validamos longitud de la contraseña
    if longitud < len(grupos):
        raise ValueError("La longitud es demasiado pequeña para los tipos seleccionados.")

    # Aseguramos al menos un carácter de cada tipo
    contrasenya = []

    for grupo in grupos:
        contrasenya.append(np.random.choice(grupo))

    # Unimos todos los grupos en uno
    pool = np.concatenate(grupos)

    # Rellenamos el resto de la contraseña
    while len(contrasenya) < longitud:
        contrasenya.append(np.random.choice(pool))

    # Mezclamos los caracteres
    contrasenya = np.array(contrasenya)
    np.random.shuffle(contrasenya)

    # Convertimos a string
    password = "".join(contrasenya)
    # Copia automática al portapapeles
    pyperclip.copy(password)

    return password

print(crear_contrasenya(10, True, True, True, True))
# Out:
# uo(EkEXu8)

# %% [markdown]
# 2. Processament de dades simple
#
# Una companya de feina ens ha demanat un favor, aprofitant que sap que estem aprenent a programar. Té un històric de partits de futbol català en un fitxer, on hi ha emmagatzemat els noms dels equips i els resultats. Necessita que processem les dades de manera automàtica, per extreure’n els resultats que necessita.
#
# Utilitza el fitxer "historic_partits.txt"
#
# Necessita un programa que retorni:
#
# El nombre total de gols que ha fet cada equip.
# El nom de l’equip més golejador.
# El nom de l’equip més golejat
# La classificació global (cada victòria: 3 pts, empat 1 pts, derrota 0 pts)

# %%
import pandas as pd
ruta = 'historic partits.txt'
archivo = pd.read_csv(ruta,
                sep="\t",
                header=None,
                names=['Equipo local','Resultado','Equipo visitante'],
                encoding="utf-8")

def clasi(archivo):
    archivo[['Goles local', 'Goles visitante']] = archivo['Resultado'].str.split("-", expand=True).astype(int)

    #Puntos
    archivo['Puntos local'] = 0
    archivo['Puntos visitante'] = 0
    archivo.loc[archivo['Goles local'] > archivo['Goles visitante'], 'Puntos local'] = 3
    archivo.loc[archivo['Goles local'] == archivo['Goles visitante'], 'Puntos local'] = 1
    archivo.loc[archivo['Goles visitante'] > archivo['Goles local'], 'Puntos visitante'] = 3
    archivo.loc[archivo['Goles visitante'] == archivo['Goles local'], 'Puntos visitante'] = 1

    # Clasificación
    Puntos_local = archivo.groupby('Equipo local')['Puntos local'].sum()
    Puntos_visitante = archivo.groupby('Equipo visitante')['Puntos visitante'].sum()
    Clasificacion = Puntos_local.add(Puntos_visitante, fill_value=0).to_frame(name="Puntos")

    # Goles a favor
    Goles_marcados_local = archivo.groupby('Equipo local')['Goles local'].sum()
    Goles_marcados_visitante = archivo.groupby('Equipo visitante')['Goles visitante'].sum()
    Total_goles_marcados = Goles_marcados_local.add(Goles_marcados_visitante, fill_value=0).to_frame(name='Goles a favor')

    # Goles en contra
    Goles_encajados_local = archivo.groupby('Equipo local')['Goles visitante'].sum()
    Goles_encajados_visitante = archivo.groupby('Equipo visitante')['Goles local'].sum()
    Total_goles_encajados = Goles_encajados_local.add(Goles_encajados_visitante, fill_value=0).to_frame(name="Goles en contra")
    
    # Clasificación final
    Clasificacion = pd.concat([Clasificacion, Total_goles_marcados, Total_goles_encajados], axis=1)
    Clasificacion['Diferencia'] = (Clasificacion['Goles a favor'] - Clasificacion['Goles en contra'])
    Clasificacion = Clasificacion.sort_values(by=['Puntos', 'Diferencia'], ascending=False)

    # Equipos destacados
    Equipo_mas_goleador = Total_goles_marcados['Goles a favor'].idxmax()
    Equipo_mas_goleado = Total_goles_encajados['Goles en contra'].idxmax()

    return Clasificacion, Equipo_mas_goleador, Equipo_mas_goleado

Clasificacion, Equipo_mas_goleador, Equipo_mas_goleado = clasi(archivo)
print(Clasificacion)
print(f'\nEl equipo que más goles ha anotado es: {Equipo_mas_goleador}')
print(f'El equipo que más goles recibe es: {Equipo_mas_goleado}')
# Out:
#                      Puntos  Goles a favor  Goles en contra  Diferencia
# Equipo local
# Girona FC                96            139               94          45
# Llagostera               94            159              142          17
# Sabadell                 85            141              121          20
# Cornellà                 82            147              146           1
# RCD Espanyol             80            131              144         -13
# Figueres                 79            161              154           7
# Lleida Esportiu          75            129              133          -4
# Terrassa                 74            147              164         -17
# FC Barcelona             73            125              115          10
# Vilafranca               72            157              172         -15
# Badalona                 68            134              124          10
# Reus Deportiu            68            119              111           8
# ...
